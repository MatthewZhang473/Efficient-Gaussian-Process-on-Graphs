# %% [markdown]
# # CSV to JSON Converter
#
# Convert random walk and GP scaling experiment CSV files to JSON format for easier data processing and analysis.

# %%
import pandas as pd
import json
import os
import glob
import re
from datetime import datetime

# Configuration - specify files to process or leave empty to use latest
SPECIFIC_FILES = {
    'rw_sampling': 'rw_sampling_stats_20250810_020458.csv',
    'sparse_gp': 'sparse_gp_scaling_stats_20250810_024906.csv', 
    'dense_gp': 'dense_gp_scaling_stats_20250810_131655.csv'
}

# Set up paths
stats_dir = os.path.join(os.getcwd(), 'stats')
print(f"Looking for CSV files in: {stats_dir}")

if not os.path.exists(stats_dir):
    print("❌ Stats directory not found")
else:
    print(f"✅ Stats directory found")
# Out:
# Looking for CSV files in: /scratches/cartwright/mz473/Efficient-Gaussian-Process-on-Graphs/experiments_sparse/scaling_exp/stats
# ✅ Stats directory found

# %% [markdown]
# ## Core Functions

# %%
def get_files_to_process(stats_dir, specific_files=None):
    """Get files to process - either specified files or latest ones"""
    file_patterns = {
        'rw_sampling': 'rw_sampling_stats*.csv',
        'sparse_gp': 'sparse_gp_scaling_stats*.csv', 
        'dense_gp': 'dense_gp_scaling_stats*.csv'
    }
    
    files_to_process = {}
    
    for file_type, pattern in file_patterns.items():
        if specific_files and file_type in specific_files:
            # Use specified file
            csv_file = os.path.join(stats_dir, specific_files[file_type])
            if os.path.exists(csv_file):
                files_to_process[file_type] = csv_file
                print(f"Using specified {file_type}: {specific_files[file_type]}")
            else:
                print(f"⚠️  Specified file not found: {specific_files[file_type]}")
        else:
            # Find latest file
            files = glob.glob(os.path.join(stats_dir, pattern))
            if files:
                latest_file = max(files, key=os.path.getmtime)
                files_to_process[file_type] = latest_file
                mod_time = datetime.fromtimestamp(os.path.getmtime(latest_file))
                print(f"Found latest {file_type}: {os.path.basename(latest_file)} (modified: {mod_time})")
    
    return files_to_process

def find_existing_json_files(stats_dir):
    """Find existing JSON files when CSV files aren't available"""
    json_patterns = {
        'rw_sampling': 'rw_sampling_stats*.json',
        'sparse_gp': 'sparse_gp_stats*.json', 
        'dense_gp': 'dense_gp_stats*.json'
    }
    
    existing_json = {}
    for file_type, pattern in json_patterns.items():
        files = glob.glob(os.path.join(stats_dir, pattern))
        if files:
            latest_file = max(files, key=os.path.getmtime)
            existing_json[file_type] = latest_file
            mod_time = datetime.fromtimestamp(os.path.getmtime(latest_file))
            print(f"Found existing JSON {file_type}: {os.path.basename(latest_file)} (modified: {mod_time})")
    
    return existing_json

def find_master_file(stats_dir):
    """Find the most recent master JSON file"""
    master_files = glob.glob(os.path.join(stats_dir, 'scaling_experiment_combined_*.json'))
    if master_files:
        latest_master = max(master_files, key=os.path.getmtime)
        mod_time = datetime.fromtimestamp(os.path.getmtime(latest_master))
        print(f"Found existing master file: {os.path.basename(latest_master)} (modified: {mod_time})")
        return latest_master
    return None

def csv_to_json_safe(csv_file, output_file):
    """Convert CSV to JSON only if JSON doesn't exist"""
    if os.path.exists(output_file):
        print(f"⏭️  JSON already exists, skipping: {os.path.basename(output_file)}")
        with open(output_file, 'r') as f:
            return json.load(f)
    
    df = pd.read_csv(csv_file)
    file_stat = os.stat(csv_file)
    
    json_data = {
        'metadata': {
            'source_file': os.path.basename(csv_file),
            'conversion_timestamp': datetime.now().isoformat(),
            'source_modified': datetime.fromtimestamp(file_stat.st_mtime).isoformat(),
            'total_records': len(df),
            'columns': list(df.columns)
        },
        'data': df.to_dict(orient='records')
    }
    
    with open(output_file, 'w') as f:
        json.dump(json_data, f, indent=2, default=str)
    
    print(f"✅ Converted {os.path.basename(csv_file)} -> {os.path.basename(output_file)}")
    return json_data

def create_master_file(converted_files, stats_dir):
    """Create combined master JSON file"""
    if not converted_files:
        return None
        
    master_timestamp = max(cf['timestamp'] for cf in converted_files)
    master_filename = f"scaling_experiment_combined_{master_timestamp}.json"
    master_filepath = os.path.join(stats_dir, master_filename)
    
    if os.path.exists(master_filepath):
        print(f"⏭️  Master file already exists: {master_filename}")
        return master_filepath
    
    master_data = {
        'conversion_info': {
            'timestamp': datetime.now().isoformat(),
            'total_files_converted': len(converted_files),
            'file_details': [{
                'type': cf['type'],
                'source': os.path.basename(cf['csv_file']),
                'record_count': cf['records']
            } for cf in converted_files]
        },
        'datasets': {}
    }
    
    # Load and combine all JSON files
    for cf in converted_files:
        with open(cf['json_file'], 'r') as f:
            master_data['datasets'][cf['type']] = json.load(f)
    
    with open(master_filepath, 'w') as f:
        json.dump(master_data, f, indent=2, default=str)
    
    print(f"✅ Created master file: {master_filename}")
    return master_filepath

print("✅ Core functions loaded")
# Out:
# ✅ Core functions loaded

# %% [markdown]
# ## Process Files

# %%
# Get files to process
files_to_process = get_files_to_process(stats_dir, SPECIFIC_FILES)

if not files_to_process:
    print("❌ No CSV files found to convert")
    print("🔍 Checking for existing JSON files...")
    existing_json = find_existing_json_files(stats_dir)
    master_filepath = find_master_file(stats_dir)
    
    if existing_json or master_filepath:
        print(f"✅ Found {len(existing_json)} individual JSON files")
        if not master_filepath and existing_json:
            print("📝 No master file found, but individual JSON files exist")
    else:
        print("❌ No JSON files found either")
        master_filepath = None
else:
    converted_files = []
    
    # Convert files
    for file_type, csv_file in files_to_process.items():
        # Extract timestamp and create JSON filename
        timestamp_match = re.search(r'_(\d{8}_\d{6})\.csv$', csv_file)
        timestamp = timestamp_match.group(1) if timestamp_match else datetime.now().strftime("%Y%m%d_%H%M%S")
        
        json_filename = f"{file_type}_stats_{timestamp}.json"
        json_filepath = os.path.join(stats_dir, json_filename)
        
        json_data = csv_to_json_safe(csv_file, json_filepath)
        converted_files.append({
            'type': file_type,
            'csv_file': csv_file,
            'json_file': json_filepath,
            'timestamp': timestamp,
            'records': len(json_data['data'])
        })
    
    # Create master file
    master_filepath = create_master_file(converted_files, stats_dir)
    
    # Summary
    total_records = sum(cf['records'] for cf in converted_files)
    print(f"\n📊 PROCESSING SUMMARY")
    print(f"   Files processed: {len(converted_files)}")
    print(f"   Total records: {total_records}")
    if master_filepath:
        print(f"   Master file: {os.path.basename(master_filepath)}")
        print(f"   File size: {os.path.getsize(master_filepath) / 1024:.1f} KB")
# Out:
# Using specified rw_sampling: rw_sampling_stats_20250810_020458.csv
# Using specified sparse_gp: sparse_gp_scaling_stats_20250810_024906.csv
# Using specified dense_gp: dense_gp_scaling_stats_20250810_131655.csv
# ⏭️  JSON already exists, skipping: rw_sampling_stats_20250810_020458.json
# ⏭️  JSON already exists, skipping: sparse_gp_stats_20250810_024906.json
# ⏭️  JSON already exists, skipping: dense_gp_stats_20250810_131655.json
# ⏭️  Master file already exists: scaling_experiment_combined_20250810_131655.json
#
# 📊 PROCESSING SUMMARY
#    Files processed: 3
#    Total records: 205
#    Master file: scaling_experiment_combined_20250810_131655.json
#    File size: 109.7 KB

# %% [markdown]
# ## Load Data for Analysis

# %%
def load_dataframes(json_file):
    """Load JSON file and return individual DataFrames"""
    with open(json_file, 'r') as f:
        data = json.load(f)
    
    dfs = {}
    if 'datasets' in data:
        for exp_type, exp_data in data['datasets'].items():
            dfs[exp_type] = pd.DataFrame(exp_data['data'])
    
    return dfs

# Load data - try master file first, then individual JSON files
master_filepath = locals().get('master_filepath') or find_master_file(stats_dir)

if master_filepath and os.path.exists(master_filepath):
    print("📖 Loading data from master file...")
    
    dfs = load_dataframes(master_filepath)
    df_rw = dfs.get('rw_sampling', pd.DataFrame())
    df_sparse_gp = dfs.get('sparse_gp', pd.DataFrame()) 
    df_dense_gp = dfs.get('dense_gp', pd.DataFrame())
    
    print(f"✅ DataFrames loaded from master file:")
    for name, df in [('df_rw', df_rw), ('df_sparse_gp', df_sparse_gp), ('df_dense_gp', df_dense_gp)]:
        print(f"   {name:12} | {len(df):4} records | {len(df.columns):2} columns")

else:
    print("📖 No master file found, trying individual JSON files...")
    existing_json = find_existing_json_files(stats_dir)
    
    if existing_json:
        df_rw = df_sparse_gp = df_dense_gp = pd.DataFrame()
        
        for file_type, json_file in existing_json.items():
            with open(json_file, 'r') as f:
                data = json.load(f)
                df = pd.DataFrame(data['data'])
                
                if file_type == 'rw_sampling':
                    df_rw = df
                elif file_type == 'sparse_gp':
                    df_sparse_gp = df
                elif file_type == 'dense_gp':
                    df_dense_gp = df
                    
                print(f"   {file_type:12} | {len(df):4} records | {len(df.columns):2} columns")
        
        print(f"✅ DataFrames loaded from individual JSON files")
    else:
        print("❌ No JSON files available")
        df_rw = df_sparse_gp = df_dense_gp = pd.DataFrame()

print(f"\n🎯 DataFrames ready: df_rw, df_sparse_gp, df_dense_gp")
# Out:
# 📖 Loading data from master file...
# ✅ DataFrames loaded from master file:
#    df_rw        |   80 records | 19 columns
#    df_sparse_gp |   80 records | 10 columns
#    df_dense_gp  |   45 records | 10 columns
#
# 🎯 DataFrames ready: df_rw, df_sparse_gp, df_dense_gp

# %% [markdown]
# ## Load Additional RW Data
#
# Load additional RW data file with more dense random walk experiments for better comparison.

# %%
# Load additional RW info file with more dense random walks
additional_rw_info = 'rw_sampling_stats_20250810_124141.csv'

# Load the additional RW data
additional_rw_file = os.path.join(stats_dir, additional_rw_info)
if os.path.exists(additional_rw_file):
    df_additional_rw = pd.read_csv(additional_rw_file)
    print(f"✅ Loaded additional RW data: {len(df_additional_rw)} records")
    print(f"Additional RW columns: {list(df_additional_rw.columns)}")
    
    # Show summary of what's in the additional data
    if 'n_nodes' in df_additional_rw.columns:
        node_counts = df_additional_rw['n_nodes'].value_counts().sort_index()
        print(f"Node counts in additional data:")
        for n_nodes, count in node_counts.items():
            print(f"  {n_nodes:6} nodes: {count:2} records")
    
    # Check if we have dense RW data that's not in the original
    if 'df_rw' in locals() and len(df_rw) > 0 and 'n_nodes' in df_rw.columns:
        original_nodes = set(df_rw['n_nodes'].unique())
        additional_nodes = set(df_additional_rw['n_nodes'].unique())
        new_nodes = additional_nodes - original_nodes
        overlapping_nodes = additional_nodes & original_nodes
        
        print(f"\nData comparison:")
        print(f"  Original RW data has {len(original_nodes)} unique node sizes")
        print(f"  Additional RW data has {len(additional_nodes)} unique node sizes")
        print(f"  New node sizes in additional data: {sorted(new_nodes)}")
        print(f"  Overlapping node sizes: {sorted(overlapping_nodes)}")
        
        # Combine datasets for comprehensive analysis
        df_rw_combined = pd.concat([df_rw, df_additional_rw], ignore_index=True)
        print(f"  Combined RW dataset: {len(df_rw_combined)} total records")
        
    else:
        # If no original RW data, use additional data as primary
        df_rw_combined = df_additional_rw.copy()
        if 'df_rw' not in locals():
            df_rw = pd.DataFrame()
        print(f"  Using additional data as primary: {len(df_rw_combined)} rows")
        
else:
    print(f"❌ Additional RW file not found: {additional_rw_info}")
    df_additional_rw = pd.DataFrame()
    if 'df_rw' in locals():
        df_rw_combined = df_rw.copy()
    else:
        df_rw = df_rw_combined = pd.DataFrame()

# Ensure all required variables exist
if 'df_sparse_gp' not in locals():
    df_sparse_gp = pd.DataFrame()
if 'df_dense_gp' not in locals():
    df_dense_gp = pd.DataFrame()

# Display column information for plotting
print(f"\n📊 Dataset summary:")
print(f"   Original RW: {len(df_rw)} records")
print(f"   Additional RW: {len(df_additional_rw)} records") 
print(f"   Combined RW: {len(df_rw_combined)} records")
if len(df_rw_combined) > 0:
    print(f"   Combined RW columns: {list(df_rw_combined.columns)}")
print(f"   Sparse GP: {len(df_sparse_gp)} records")
print(f"   Dense GP: {len(df_dense_gp)} records")
# Out:
# ✅ Loaded additional RW data: 45 records
# Additional RW columns: ['n_nodes', 'n_edges', 'seed', 'sparse_rw_time', 'dense_rw_time', 'sparse_size_mb', 'dense_size_mb', 'sparse_dense_equiv_mb', 'compression_ratio', 'time_speedup', 'sparse_file_size_mb', 'dense_file_size_mb', 'sparse_total_nnz', 'sparse_avg_nnz_per_matrix', 'graph_sparsity', 'step_matrix_sparsity', 'run_dense', 'is_feasible', 'has_dense_data']
# Node counts in additional data:
#       32 nodes:  5 records
#       64 nodes:  5 records
#      128 nodes:  5 records
#      256 nodes:  5 records
#      512 nodes:  5 records
#     1024 nodes:  5 records
#     2048 nodes:  5 records
#     4096 nodes:  5 records
#     8192 nodes:  5 records
#
# Data comparison:
#   Original RW data has 16 unique node sizes
#   Additional RW data has 9 unique node sizes
#   New node sizes in additional data: []
#   Overlapping node sizes: [32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]
#   Combined RW dataset: 125 total records
#
# 📊 Dataset summary:
#    Original RW: 80 records
#    Additional RW: 45 records
#    Combined RW: 125 records
#    Combined RW columns: ['n_nodes', 'n_edges', 'seed', 'sparse_rw_time', 'dense_rw_time', 'sparse_size_mb', 'dense_size_mb', 'sparse_dense_equiv_mb', 'compression_ratio', 'time_speedup', 'sparse_file_size_mb', 'dense_file_size_mb', 'sparse_total_nnz', 'sparse_avg_nnz_per_matrix', 'graph_sparsity', 'step_matrix_sparsity', 'run_dense', 'is_feasible', 'has_dense_data']
#    Sparse GP: 80 records
#    Dense GP: 45 records

# %% [markdown]
# ## Visualization
#
# Comprehensive scaling analysis plots with mean and ± 2 std, comparing sparse vs dense approaches across all metrics.
#
# Each plot in one code block with combined data from original and additional RW experiments.

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Memory scaling curve (object size, log-log)
plt.figure(figsize=(6, 6))

# Use combined RW data for memory comparison
if len(df_rw_combined) > 0 and 'n_nodes' in df_rw_combined.columns:
    if 'sparse_size_mb' in df_rw_combined.columns:
        sparse_grouped = df_rw_combined.groupby('n_nodes')['sparse_size_mb'].agg(['mean', 'std']).reset_index()
        plt.errorbar(sparse_grouped['n_nodes'], sparse_grouped['mean'], 
                    yerr=2*sparse_grouped['std'], label='Sparse Memory', marker='o', capsize=5, alpha=0.8)
    
    if 'dense_size_mb' in df_rw_combined.columns:
        dense_grouped = df_rw_combined.groupby('n_nodes')['dense_size_mb'].agg(['mean', 'std']).reset_index()
        plt.errorbar(dense_grouped['n_nodes'], dense_grouped['mean'], 
                    yerr=2*dense_grouped['std'], label='Dense Memory', marker='s', capsize=5, alpha=0.8)

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Nodes')
plt.ylabel('Memory Usage (MB)')
plt.title('Memory Scaling Comparison (Combined Data)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# 2. Kernel initialization time (Random Walk), log-log
plt.figure(figsize=(6, 6))

# Use combined RW data for timing comparison
if len(df_rw_combined) > 0 and 'n_nodes' in df_rw_combined.columns:
    if 'sparse_rw_time' in df_rw_combined.columns:
        sparse_rw_grouped = df_rw_combined.groupby('n_nodes')['sparse_rw_time'].agg(['mean', 'std']).reset_index()
        plt.errorbar(sparse_rw_grouped['n_nodes'], sparse_rw_grouped['mean'], 
                    yerr=2*sparse_rw_grouped['std'], label='Sparse RW Time', marker='o', capsize=5, alpha=0.8)
    
    if 'dense_rw_time' in df_rw_combined.columns:
        dense_rw_grouped = df_rw_combined.groupby('n_nodes')['dense_rw_time'].agg(['mean', 'std']).reset_index()
        plt.errorbar(dense_rw_grouped['n_nodes'], dense_rw_grouped['mean'], 
                    yerr=2*dense_rw_grouped['std'], label='Dense RW Time', marker='s', capsize=5, alpha=0.8)

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Nodes')
plt.ylabel('Random Walk Time (s)')
plt.title('Kernel Initialization Time Scaling (Combined RW Data)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# 3. Training time scaling, log-log
plt.figure(figsize=(6, 6))

if len(df_sparse_gp) > 0 and 'n_nodes' in df_sparse_gp.columns and 'train_time' in df_sparse_gp.columns:
    sparse_grouped = df_sparse_gp.groupby('n_nodes')['train_time'].agg(['mean', 'std']).reset_index()
    plt.errorbar(sparse_grouped['n_nodes'], sparse_grouped['mean'], 
                yerr=2*sparse_grouped['std'], label='Sparse GP Training', marker='o', capsize=5, alpha=0.8)

if len(df_dense_gp) > 0 and 'n_nodes' in df_dense_gp.columns and 'train_time' in df_dense_gp.columns:
    dense_grouped = df_dense_gp.groupby('n_nodes')['train_time'].agg(['mean', 'std']).reset_index()
    plt.errorbar(dense_grouped['n_nodes'], dense_grouped['mean'], 
                yerr=2*dense_grouped['std'], label='Dense GP Training', marker='s', capsize=5, alpha=0.8)

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Nodes')
plt.ylabel('Training Time (s)')
plt.title('GP Training Time Scaling Comparison')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# 4. Inference time scaling, log-log
plt.figure(figsize=(6, 6))

if len(df_sparse_gp) > 0 and 'n_nodes' in df_sparse_gp.columns and 'inference_time' in df_sparse_gp.columns:
    sparse_grouped = df_sparse_gp.groupby('n_nodes')['inference_time'].agg(['mean', 'std']).reset_index()
    plt.errorbar(sparse_grouped['n_nodes'], sparse_grouped['mean'], 
                yerr=2*sparse_grouped['std'], label='Sparse GP Inference', marker='o', capsize=5, alpha=0.8)

if len(df_dense_gp) > 0 and 'n_nodes' in df_dense_gp.columns and 'inference_time' in df_dense_gp.columns:
    dense_grouped = df_dense_gp.groupby('n_nodes')['inference_time'].agg(['mean', 'std']).reset_index()
    plt.errorbar(dense_grouped['n_nodes'], dense_grouped['mean'], 
                yerr=2*dense_grouped['std'], label='Dense GP Inference', marker='s', capsize=5, alpha=0.8)

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Nodes')
plt.ylabel('Inference Time (s)')
plt.title('GP Inference Time Scaling Comparison')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# 5. Combined overview plot - All timing metrics
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# Memory scaling
if len(df_rw_combined) > 0 and 'n_nodes' in df_rw_combined.columns:
    if 'sparse_size_mb' in df_rw_combined.columns:
        sparse_grouped = df_rw_combined.groupby('n_nodes')['sparse_size_mb'].agg(['mean', 'std']).reset_index()
        ax1.errorbar(sparse_grouped['n_nodes'], sparse_grouped['mean'], 
                    yerr=2*sparse_grouped['std'], label='Sparse', marker='o', capsize=3)
    
    if 'dense_size_mb' in df_rw_combined.columns:
        dense_grouped = df_rw_combined.groupby('n_nodes')['dense_size_mb'].agg(['mean', 'std']).reset_index()
        ax1.errorbar(dense_grouped['n_nodes'], dense_grouped['mean'], 
                    yerr=2*dense_grouped['std'], label='Dense', marker='s', capsize=3)

ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Number of Nodes')
ax1.set_ylabel('Memory (MB)')
ax1.set_title('Memory Scaling')
ax1.legend()
ax1.grid(True, alpha=0.3)

# RW time scaling
if len(df_rw_combined) > 0 and 'n_nodes' in df_rw_combined.columns:
    if 'sparse_rw_time' in df_rw_combined.columns:
        sparse_rw_grouped = df_rw_combined.groupby('n_nodes')['sparse_rw_time'].agg(['mean', 'std']).reset_index()
        ax2.errorbar(sparse_rw_grouped['n_nodes'], sparse_rw_grouped['mean'], 
                    yerr=2*sparse_rw_grouped['std'], label='Sparse', marker='o', capsize=3)
    
    if 'dense_rw_time' in df_rw_combined.columns:
        dense_rw_grouped = df_rw_combined.groupby('n_nodes')['dense_rw_time'].agg(['mean', 'std']).reset_index()
        ax2.errorbar(dense_rw_grouped['n_nodes'], dense_rw_grouped['mean'], 
                    yerr=2*dense_rw_grouped['std'], label='Dense', marker='s', capsize=3)

ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('Number of Nodes')
ax2.set_ylabel('RW Time (s)')
ax2.set_title('Random Walk Time')
ax2.legend()
ax2.grid(True, alpha=0.3)

# Training time scaling
if len(df_sparse_gp) > 0 and 'train_time' in df_sparse_gp.columns:
    sparse_grouped = df_sparse_gp.groupby('n_nodes')['train_time'].agg(['mean', 'std']).reset_index()
    ax3.errorbar(sparse_grouped['n_nodes'], sparse_grouped['mean'], 
                yerr=2*sparse_grouped['std'], label='Sparse', marker='o', capsize=3)

if len(df_dense_gp) > 0 and 'train_time' in df_dense_gp.columns:
    dense_grouped = df_dense_gp.groupby('n_nodes')['train_time'].agg(['mean', 'std']).reset_index()
    ax3.errorbar(dense_grouped['n_nodes'], dense_grouped['mean'], 
                yerr=2*dense_grouped['std'], label='Dense', marker='s', capsize=3)

ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.set_xlabel('Number of Nodes')
ax3.set_ylabel('Training Time (s)')
ax3.set_title('GP Training Time')
ax3.legend()
ax3.grid(True, alpha=0.3)

# Inference time scaling
if len(df_sparse_gp) > 0 and 'inference_time' in df_sparse_gp.columns:
    sparse_grouped = df_sparse_gp.groupby('n_nodes')['inference_time'].agg(['mean', 'std']).reset_index()
    ax4.errorbar(sparse_grouped['n_nodes'], sparse_grouped['mean'], 
                yerr=2*sparse_grouped['std'], label='Sparse', marker='o', capsize=3)

if len(df_dense_gp) > 0 and 'inference_time' in df_dense_gp.columns:
    dense_grouped = df_dense_gp.groupby('n_nodes')['inference_time'].agg(['mean', 'std']).reset_index()
    ax4.errorbar(dense_grouped['n_nodes'], dense_grouped['mean'], 
                yerr=2*dense_grouped['std'], label='Dense', marker='s', capsize=3)

ax4.set_xscale('log')
ax4.set_yscale('log')
ax4.set_xlabel('Number of Nodes')
ax4.set_ylabel('Inference Time (s)')
ax4.set_title('GP Inference Time')
ax4.legend()
ax4.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\n📊 Visualization complete using combined datasets:")
print(f"   Combined RW data: {len(df_rw_combined)} records")
print(f"   Sparse GP data: {len(df_sparse_gp)} records")
print(f"   Dense GP data: {len(df_dense_gp)} records")
# Out:
# 📊 Visualization complete using combined datasets:
#    Combined RW data: 125 records
#    Sparse GP data: 80 records
#    Dense GP data: 45 records
