# %%
import pandas as pd

gp_comparison_path = "/Users/matthew/Documents/Efficient Gaussian Process on Graphs/Efficient_Gaussian_Process_On_Graphs/experiments_sparse/results/comparison_20250804_233659/gp_comparison.csv"
rw_comparison_path = "/Users/matthew/Documents/Efficient Gaussian Process on Graphs/Efficient_Gaussian_Process_On_Graphs/experiments_sparse/results/comparison_20250804_233659/random_walk_comparison.csv"

# %%
gp_comparison = pd.read_csv(gp_comparison_path)
rw_comparison = pd.read_csv(rw_comparison_path)

# %%
rw_comparison.columns
# Out:
# Index(['nodes', 'edges', 'sparsity', 'dense_time', 'sparse_time',
#        'dense_memory', 'sparse_memory', 'dense_obj_mb', 'sparse_obj_mb',
#        'time_speedup', 'memory_efficiency', 'obj_compression'],
#       dtype='object')

# %%
gp_comparison.columns
# Out:
# Index(['nodes', 'n_epochs', 'sparse_only', 'dense_kernel_init',
#        'dense_training', 'dense_inference', 'dense_total',
#        'sparse_kernel_init', 'sparse_training', 'sparse_inference',
#        'sparse_total', 'dense_memory', 'sparse_memory', 'dense_rmse',
#        'sparse_rmse', 'dense_ll', 'sparse_ll', 'kernel_speedup',
#        'training_speedup', 'inference_speedup', 'total_speedup',
#        'memory_efficiency'],
#       dtype='object')

# %%
gp_comparison[['nodes','sparse_kernel_init', 'sparse_training', 'sparse_inference', 'dense_kernel_init', 'dense_training', 'dense_inference']]
# Out:
#    nodes  sparse_kernel_init  sparse_training  sparse_inference  \
# 0    100            1.765272         0.438134          0.012917
# 1    200            3.494416         0.555577          0.018051
# 2    400            6.786113         0.776754          0.027715
# 3    800           13.581612         1.809788          0.068001
# 4   1600           25.803351         2.517202          0.115508
# 5   3200           53.265306         3.824546          0.146850
# 6   6400          111.448560         8.104730          0.373766
#
#    dense_kernel_init  dense_training  dense_inference
# 0           1.608860        0.648253         0.016784
# 1           3.012853        0.436387         0.017646
# 2           6.480300        0.608281         0.028628
# 3          16.083188        2.254354         0.083256
# 4          45.754107        7.142557         0.473585
# 5         138.187686       47.967923         3.476148
# 6         464.713083      392.505450        28.568144

# %%
rw_comparison[['nodes', 'dense_obj_mb', 'sparse_obj_mb', 'obj_compression']]
# Out:
#    nodes  dense_obj_mb  sparse_obj_mb  obj_compression
# 0    100      0.305176       0.136795         2.230898
# 1    200      1.220703       0.340683         3.583106
# 2    500      7.629395       0.641907        11.885519
# 3   1000     30.517578       1.387268        21.998328
# 4   2000    122.070312       1.911179        63.871746

# %%
63.871746/1.911179
# Out:
# 33.42007525197797

# %%
392.5 / 8.1
# Out:
# 48.45679012345679

# %%
28.56 / 0.37
# Out:
# 77.1891891891892
